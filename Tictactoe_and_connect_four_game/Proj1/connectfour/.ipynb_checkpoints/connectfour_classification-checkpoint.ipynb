# %% [markdown]
# # Connect four classification

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_curve, roc_auc_score, confusion_matrix 
from sklearn.model_selection import cross_val_score
import seaborn as sns
import pickle

# %%
data =  pd.read_csv('connectfour.data', sep=",")
data=data.drop('win', axis = 1)
print(data)
# Out:
#        b b.1 b.2 b.3 b.4 b.5 b.6 b.7 b.8 b.9  ... b.24 b.25 b.26 b.27 b.28  \
# 0      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 1      b   b   b   b   b   b   o   b   b   b  ...    b    b    b    b    b
# 2      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 3      o   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 4      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    o
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 67551  x   x   b   b   b   b   o   x   o   b  ...    b    b    b    b    o
# 67552  x   x   b   b   b   b   o   b   b   b  ...    b    b    b    b    o
# 67553  x   x   b   b   b   b   o   o   b   b  ...    b    b    b    b    o
# 67554  x   o   b   b   b   b   o   b   b   b  ...    b    b    b    b    o
# 67555  x   o   o   o   x   b   o   b   b   b  ...    b    b    b    b    x
#
#       b.29 b.30 b.31 b.32 b.33
# 0        b    b    b    b    b
# 1        b    b    b    b    b
# 2        b    b    b    b    b
# 3        b    b    b    b    b
# 4        b    b    b    b    b
# ...    ...  ...  ...  ...  ...
# 67551    o    x    b    b    b
# 67552    x    o    o    x    b
# 67553    x    x    o    b    b
# 67554    x    o    x    x    b
# 67555    b    b    b    b    b
#
# [67556 rows x 42 columns]

# %%
y_df = pd.read_csv('generated_data_y.csv',header=None)
y = y_df.iloc[:,1]
y
# Out:
# 0        4.0
# 1        0.0
# 2        4.0
# 3        4.0
# 4        4.0
#         ...
# 67551    3.0
# 67552    3.0
# 67553    3.0
# 67554    3.0
# 67555    3.0
# Name: 1, Length: 67556, dtype: float64

# %%
data=data.join(y)
data
# Out:
#        b b.1 b.2 b.3 b.4 b.5 b.6 b.7 b.8 b.9  ... b.25 b.26 b.27 b.28 b.29  \
# 0      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 1      b   b   b   b   b   b   o   b   b   b  ...    b    b    b    b    b
# 2      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 3      o   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 4      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    o    b
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 67551  x   x   b   b   b   b   o   x   o   b  ...    b    b    b    o    o
# 67552  x   x   b   b   b   b   o   b   b   b  ...    b    b    b    o    x
# 67553  x   x   b   b   b   b   o   o   b   b  ...    b    b    b    o    x
# 67554  x   o   b   b   b   b   o   b   b   b  ...    b    b    b    o    x
# 67555  x   o   o   o   x   b   o   b   b   b  ...    b    b    b    x    b
#
#       b.30 b.31 b.32 b.33    1
# 0        b    b    b    b  4.0
# 1        b    b    b    b  0.0
# 2        b    b    b    b  4.0
# 3        b    b    b    b  4.0
# 4        b    b    b    b  4.0
# ...    ...  ...  ...  ...  ...
# 67551    x    b    b    b  3.0
# 67552    o    o    x    b  3.0
# 67553    x    o    b    b  3.0
# 67554    o    x    x    b  3.0
# 67555    b    b    b    b  3.0
#
# [67556 rows x 43 columns]

# %%
data.iloc[0].unique()
# Out:
# array(['b', 'x', 'o', 4.0], dtype=object)

# %%
y_df.iloc[:,1].unique()
# Out:
# array([ 4.,  0.,  2.,  1.,  6.,  5., nan,  3.])

# %%
col=data.columns.tolist()
print(col)
# Out:
# ['b', 'b.1', 'b.2', 'b.3', 'b.4', 'b.5', 'b.6', 'b.7', 'b.8', 'b.9', 'b.10', 'b.11', 'x', 'o', 'b.12', 'b.13', 'b.14', 'b.15', 'x.1', 'o.1', 'x.2', 'o.2', 'x.3', 'o.3', 'b.16', 'b.17', 'b.18', 'b.19', 'b.20', 'b.21', 'b.22', 'b.23', 'b.24', 'b.25', 'b.26', 'b.27', 'b.28', 'b.29', 'b.30', 'b.31', 'b.32', 'b.33', 1]

# %%
data[data.isnull().any(axis=1)]
# Out:
#        b b.1 b.2 b.3 b.4 b.5 b.6 b.7 b.8 b.9  ... b.25 b.26 b.27 b.28 b.29  \
# 2564   o   b   b   b   b   b   x   x   o   b  ...    b    b    b    b    b
# 2570   o   x   b   b   b   b   x   b   b   b  ...    b    b    b    b    b
# 2603   b   b   b   b   b   b   o   o   b   b  ...    b    b    b    x    b
# 2606   b   b   b   b   b   b   o   b   b   b  ...    b    b    b    x    o
# 2646   x   o   b   b   b   b   o   b   b   b  ...    b    b    b    x    b
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 50677  b   b   b   b   b   b   x   o   x   b  ...    b    b    b    x    b
# 50679  o   b   b   b   b   b   x   x   x   o  ...    b    b    b    b    b
# 50690  b   b   b   b   b   b   x   b   b   b  ...    b    b    b    x    o
# 50831  x   b   b   b   b   b   x   o   o   b  ...    b    b    b    o    x
# 51142  x   b   b   b   b   b   x   o   b   b  ...    b    b    b    x    x
#
#       b.30 b.31 b.32 b.33   1
# 2564     b    b    b    b NaN
# 2570     b    b    b    b NaN
# 2603     b    b    b    b NaN
# 2606     b    b    b    b NaN
# 2646     b    b    b    b NaN
# ...    ...  ...  ...  ...  ..
# 50677    b    b    b    b NaN
# 50679    b    b    b    b NaN
# 50690    b    b    b    b NaN
# 50831    b    b    b    b NaN
# 51142    b    b    b    b NaN
#
# [220 rows x 43 columns]

# %%
data=data.dropna()

# %%
#X and Y
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X
# Out:
#        b b.1 b.2 b.3 b.4 b.5 b.6 b.7 b.8 b.9  ... b.24 b.25 b.26 b.27 b.28  \
# 0      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 1      b   b   b   b   b   b   o   b   b   b  ...    b    b    b    b    b
# 2      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 3      o   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    b
# 4      b   b   b   b   b   b   b   b   b   b  ...    b    b    b    b    o
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 67551  x   x   b   b   b   b   o   x   o   b  ...    b    b    b    b    o
# 67552  x   x   b   b   b   b   o   b   b   b  ...    b    b    b    b    o
# 67553  x   x   b   b   b   b   o   o   b   b  ...    b    b    b    b    o
# 67554  x   o   b   b   b   b   o   b   b   b  ...    b    b    b    b    o
# 67555  x   o   o   o   x   b   o   b   b   b  ...    b    b    b    b    x
#
#       b.29 b.30 b.31 b.32 b.33
# 0        b    b    b    b    b
# 1        b    b    b    b    b
# 2        b    b    b    b    b
# 3        b    b    b    b    b
# 4        b    b    b    b    b
# ...    ...  ...  ...  ...  ...
# 67551    o    x    b    b    b
# 67552    x    o    o    x    b
# 67553    x    x    o    b    b
# 67554    x    o    x    x    b
# 67555    b    b    b    b    b
#
# [67336 rows x 42 columns]

# %%
y.unique()
# Out:
# array([4., 0., 2., 1., 6., 5., 3.])

# %%
#Label encoding
le = preprocessing.LabelEncoder()

# %%
#Transforming X
for i in range(len(col)-1):
    X[col[i]]=le.fit_transform(X[col[i]])

# %%
X.shape
# Out:
# (67336, 42)

# %%
y.shape
# Out:
# (67336,)

# %%
#Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (53868, 42)

# %%
X_test.shape
# Out:
# (13468, 42)

# %%
mlp = make_pipeline(MLPClassifier(hidden_layer_sizes=(500, 150, 100, 50,), 
                                  activation='relu', max_iter=200, tol=0.5))
mlp.fit(X_train, y_train)

y_pred_mlp = mlp.predict(X_test)
y_pred_mlp
# Out:
# array([1., 4., 3., ..., 2., 3., 2.])

# %%
accuracy_score(y_test,y_pred_mlp)
# Out:
# 0.6402583902583903

# %%
recall_score(y_test,y_pred_mlp,average='macro')
# Out:
# 0.44167740501190106

# %%
accuracy_score(y_test,y_pred_mlp)
# Out:
# 0.6402583902583903

# %%
recall_score(y_test,y_pred_mlp,average='macro')
# Out:
# 0.44167740501190106

# %%
precision_score(y_test,y_pred_mlp,average='macro')
# Out:
# 0.48828801132907845

# %%
f1_score(y_test,y_pred_mlp,average='macro')
# Out:
# 0.4427730498314519

# %%
conf_mat = confusion_matrix(y_test, y_pred_mlp)
sns.heatmap(conf_mat, square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
# Out:
# <AxesSubplot:>

# %%
# save the model to disk
filename = 'final_mlp_model.pkl'
pickle.dump(mlp, open(filename, 'wb'))
